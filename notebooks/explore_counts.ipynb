# %%
import pandas as pd
counts_path = "../data/GSE138852/GSE138852_counts.csv"
counts_df = pd.read_csv(counts_path, index_col=0)
counts_df.head()
# Out:
#                AAACCTGGTAGAAAGG_AD5_AD6  AAACCTGGTAGCGATG_AD5_AD6  \
# FO538757.2                            0                         0
# AP006222.2                            0                         0
# RP5-857K21.4                          0                         0
# RP11-206L10.9                         0                         0
# NOC2L                                 0                         0
#
#                AAACCTGTCAGTCAGT_AD5_AD6  AAACCTGTCCAAACAC_AD5_AD6  \
# FO538757.2                            0                         0
# AP006222.2                            0                         0
# RP5-857K21.4                          0                         0
# RP11-206L10.9                         0                         0
# NOC2L                                 0                         0
#
#                AAACCTGTCCAGTATG_AD5_AD6  AAAGCAACATGGGAAC_AD5_AD6  \
# FO538757.2                            0                         1
# ...
